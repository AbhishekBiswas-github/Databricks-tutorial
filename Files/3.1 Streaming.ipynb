# %%
dbutils.fs.mkdirs("/Volumes/demoworkspace_new/default/my_volume/ecommerce")

# 1. Customers JSON (20 entries)
customers_json = (
    '{"customer_id": 1, "email": "alice@example.com", "profile": {"first_name": "Alice", "last_name": "Smith", "gender": "Female", "address": {"street": "123 Main St", "city": "New York", "country": "USA"}}, "updated_at": "2026-06-01 08:30:00"}\n'
    '{"customer_id": 2, "email": "bob@example.com", "profile": {"first_name": "Bob", "last_name": "Johnson", "gender": "Male", "address": {"street": "456 Market St", "city": "Chicago", "country": "USA"}}, "updated_at": "2026-06-02 09:15:00"}\n'
    '{"customer_id": 3, "email": "charlie@example.com", "profile": {"first_name": "Charlie", "last_name": "Brown", "gender": "Male", "address": {"street": "789 Broadway", "city": "San Francisco", "country": "USA"}}, "updated_at": "2026-06-03 11:00:00"}\n'
    '{"customer_id": 4, "email": "diana@example.com", "profile": {"first_name": "Diana", "last_name": "Prince", "gender": "Female", "address": {"street": "321 Oak Rd", "city": "Austin", "country": "USA"}}, "updated_at": "2026-06-04 14:20:00"}\n'
    '{"customer_id": 5, "email": "evan@example.com", "profile": {"first_name": "Evan", "last_name": "Davis", "gender": "Male", "address": {"street": "654 Pine St", "city": "Seattle", "country": "USA"}}, "updated_at": "2026-06-05 16:45:00"}\n'
    '{"customer_id": 6, "email": "fiona@example.com", "profile": {"first_name": "Fiona", "last_name": "Gallagher", "gender": "Female", "address": {"street": "987 Elm St", "city": "Boston", "country": "USA"}}, "updated_at": "2026-06-06 10:10:00"}\n'
    '{"customer_id": 7, "email": "george@example.com", "profile": {"first_name": "George", "last_name": "Miller", "gender": "Male", "address": {"street": "111 Maple Ave", "city": "Denver", "country": "USA"}}, "updated_at": "2026-06-07 12:00:00"}\n'
    '{"customer_id": 8, "email": "hannah@example.com", "profile": {"first_name": "Hannah", "last_name": "Wilson", "gender": "Female", "address": {"street": "222 Cedar St", "city": "Atlanta", "country": "USA"}}, "updated_at": "2026-06-08 09:50:00"}\n'
    '{"customer_id": 9, "email": "ian@example.com", "profile": {"first_name": "Ian", "last_name": "Taylor", "gender": "Male", "address": {"street": "333 Birch Rd", "city": "Portland", "country": "USA"}}, "updated_at": "2026-06-09 15:30:00"}\n'
    '{"customer_id": 10, "email": "julia@example.com", "profile": {"first_name": "Julia", "last_name": "Anderson", "gender": "Female", "address": {"street": "444 Walnut St", "city": "Miami", "country": "USA"}}, "updated_at": "2026-06-10 11:25:00"}\n'
    '{"customer_id": 11, "email": "kevin@example.com", "profile": {"first_name": "Kevin", "last_name": "Thomas", "gender": "Male", "address": {"street": "555 Lake Ave", "city": "Dallas", "country": "USA"}}, "updated_at": "2026-06-11 08:00:00"}\n'
    '{"customer_id": 12, "email": "laura@example.com", "profile": {"first_name": "Laura", "last_name": "Jackson", "gender": "Female", "address": {"street": "666 Hill St", "city": "Phoenix", "country": "USA"}}, "updated_at": "2026-06-11 09:30:00"}\n'
    '{"customer_id": 13, "email": "michael@example.com", "profile": {"first_name": "Michael", "last_name": "White", "gender": "Male", "address": {"street": "777 Park Rd", "city": "Philadelphia", "country": "USA"}}, "updated_at": "2026-06-12 10:15:00"}\n'
    '{"customer_id": 14, "email": "nina@example.com", "profile": {"first_name": "Nina", "last_name": "Harris", "gender": "Female", "address": {"street": "888 Beach Blvd", "city": "San Diego", "country": "USA"}}, "updated_at": "2026-06-12 12:40:00"}\n'
    '{"customer_id": 15, "email": "oscar@example.com", "profile": {"first_name": "Oscar", "last_name": "Martin", "gender": "Male", "address": {"street": "999 River St", "city": "Detroit", "country": "USA"}}, "updated_at": "2026-06-13 14:10:00"}\n'
    '{"customer_id": 16, "email": "paula@example.com", "profile": {"first_name": "Paula", "last_name": "Clark", "gender": "Female", "address": {"street": "124 Forest Ave", "city": "Minneapolis", "country": "USA"}}, "updated_at": "2026-06-13 15:20:00"}\n'
    '{"customer_id": 17, "email": "quentin@example.com", "profile": {"first_name": "Quentin", "last_name": "Rodriguez", "gender": "Male", "address": {"street": "235 Valley Rd", "city": "Tampa", "country": "USA"}}, "updated_at": "2026-06-14 16:00:00"}\n'
    '{"customer_id": 18, "email": "rachel@example.com", "profile": {"first_name": "Rachel", "last_name": "Lewis", "gender": "Female", "address": {"street": "346 Sunset Dr", "city": "Las Vegas", "country": "USA"}}, "updated_at": "2026-06-14 17:30:00"}\n'
    '{"customer_id": 19, "email": "sam@example.com", "profile": {"first_name": "Sam", "last_name": "Lee", "gender": "Male", "address": {"street": "457 Ocean Ave", "city": "Orlando", "country": "USA"}}, "updated_at": "2026-06-15 09:10:00"}\n'
    '{"customer_id": 20, "email": "tina@example.com", "profile": {"first_name": "Tina", "last_name": "Walker", "gender": "Female", "address": {"street": "568 Canyon Way", "city": "Salt Lake City", "country": "USA"}}, "updated_at": "2026-06-15 11:00:00"}}'
)
dbutils.fs.put("/Volumes/demoworkspace_new/default/my_volume/ecommerce/customers.json", customers_json, overwrite=True)

# 2. Books JSON (10 entries)
books_json = (
    '{"book_id": 101, "title": "Databricks Essentials", "author": "John Doe", "category": "Tech", "price": 45.99}\n'
    '{"book_id": 102, "title": "Atomic Habits", "author": "James Clear", "category": "Self-Help", "price": 20.00}\n'
    '{"book_id": 103, "title": "Deep Work", "author": "Cal Newport", "category": "Productivity", "price": 25.50}\n'
    '{"book_id": 104, "title": "Learning Spark", "author": "Holden Karau", "category": "Tech", "price": 55.00}\n'
    '{"book_id": 105, "title": "The Psychology of Money", "author": "Morgan Housel", "category": "Finance", "price": 30.00}\n'
    '{"book_id": 106, "title": "Clean Code", "author": "Robert Martin", "category": "Tech", "price": 42.00}\n'
    '{"book_id": 107, "title": "Rich Dad Poor Dad", "author": "Robert Kiyosaki", "category": "Finance", "price": 24.99}\n'
    '{"book_id": 108, "title": "The 7 Habits of Highly Effective People", "author": "Stephen Covey", "category": "Self-Help", "price": 22.50}\n'
    '{"book_id": 109, "title": "Designing Data-Intensive Applications", "author": "Martin Kleppmann", "category": "Tech", "price": 58.50}\n'
    '{"book_id": 110, "title": "Thinking, Fast and Slow", "author": "Daniel Kahneman", "category": "Psychology", "price": 28.00}'
)
dbutils.fs.put("/Volumes/demoworkspace_new/default/my_volume/ecommerce/books.json", books_json, overwrite=True)

# 3. Orders JSON (18 entries)
orders_json = (
    '{"order_id": 1001, "timestamp": "2026-06-11 10:00:00", "customer_id": 1, "quantity": 2, "total": 100.99, "books": [{"book_id": 101, "qty": 1}, {"book_id": 106, "qty": 1}]}\n'
    '{"order_id": 1002, "timestamp": "2026-06-11 11:30:00", "customer_id": 2, "quantity": 1, "total": 55.00, "books": [{"book_id": 102, "qty": 1}]}\n'
    '{"order_id": 1003, "timestamp": "2026-06-12 09:15:00", "customer_id": 3, "quantity": 3, "total": 128.50, "books": [{"book_id": 103, "qty": 1}, {"book_id": 107, "qty": 2}]}\n'
    '{"order_id": 1004, "timestamp": "2026-06-12 14:00:00", "customer_id": 4, "quantity": 1, "total": 60.00, "books": [{"book_id": 104, "qty": 1}]}\n'
    '{"order_id": 1005, "timestamp": "2026-06-13 16:20:00", "customer_id": 5, "quantity": 2, "total": 97.99, "books": [{"book_id": 105, "qty": 1}, {"book_id": 108, "qty": 1}]}\n'
    '{"order_id": 1006, "timestamp": "2026-06-14 10:45:00", "customer_id": 6, "quantity": 1, "total": 48.00, "books": [{"book_id": 109, "qty": 1}]}\n'
    '{"order_id": 1007, "timestamp": "2026-06-14 13:10:00", "customer_id": 7, "quantity": 1, "total": 58.50, "books": [{"book_id": 110, "qty": 1}]}\n'
    '{"order_id": 1008, "timestamp": "2026-06-15 11:00:00", "customer_id": 8, "quantity": 2, "total": 45.50, "books": [{"book_id": 106, "qty": 1}, {"book_id": 107, "qty": 1}]}\n'
    '{"order_id": 1009, "timestamp": "2026-06-15 15:55:00", "customer_id": 9, "quantity": 1, "total": 45.99, "books": [{"book_id": 101, "qty": 1}]}\n'
    '{"order_id": 1010, "timestamp": "2026-06-16 12:40:00", "customer_id": 10, "quantity": 2, "total": 105.00, "books": [{"book_id": 102, "qty": 1}, {"book_id": 105, "qty": 1}]}\n'
    '{"order_id": 1011, "timestamp": "2026-06-16 14:10:00", "customer_id": 11, "quantity": 1, "total": 39.99, "books": [{"book_id": 103, "qty": 1}]}\n'
    '{"order_id": 1012, "timestamp": "2026-06-17 09:20:00", "customer_id": 12, "quantity": 2, "total": 85.00, "books": [{"book_id": 106, "qty": 2}]}\n'
    '{"order_id": 1013, "timestamp": "2026-06-17 11:05:00", "customer_id": 13, "quantity": 1, "total": 60.00, "books": [{"book_id": 104, "qty": 1}]}\n'
    '{"order_id": 1014, "timestamp": "2026-06-18 13:30:00", "customer_id": 14, "quantity": 3, "total": 140.00, "books": [{"book_id": 101, "qty": 1}, {"book_id": 102, "qty": 1}, {"book_id": 106, "qty": 1}]}\n'
    '{"order_id": 1015, "timestamp": "2026-06-18 15:45:00", "customer_id": 15, "quantity": 1, "total": 49.99, "books": [{"book_id": 105, "qty": 1}]}\n'
    '{"order_id": 1016, "timestamp": "2026-06-19 10:15:00", "customer_id": 16, "quantity": 2, "total": 93.98, "books": [{"book_id": 108, "qty": 2}]}\n'
    '{"order_id": 1017, "timestamp": "2026-06-19 12:00:00", "customer_id": 17, "quantity": 1, "total": 48.00, "books": [{"book_id": 109, "qty": 1}]}\n'
    '{"order_id": 1018, "timestamp": "2026-06-19 16:30:00", "customer_id": 18, "quantity": 1, "total": 58.50, "books": [{"book_id": 110, "qty": 1}]}'
)
dbutils.fs.put("/Volumes/demoworkspace_new/default/my_volume/ecommerce/orders.json", orders_json, overwrite=True)

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType, ArrayType

orders_schema = StructType([
    StructField("order_id", IntegerType()),
    StructField("timestamp", StringType()),   # cast to TimestampType later if needed
    StructField("customer_id", IntegerType()),
    StructField("quantity", IntegerType()),
    StructField("total", DoubleType()),
    StructField("books", ArrayType(
        StructType([
            StructField("book_id", IntegerType()),
            StructField("qty", IntegerType())
        ])
    ))
])

streaming_df = (spark.readStream
    .format("json")  # or "cloudFiles" for Auto Loader, "kafka", etc.
    .schema(orders_schema)
    .option("maxFilesPerTrigger", 1)
    .load("/Volumes/demoworkspace_new/default/my_volume/ecommerce/orders.json"))

# %%
query = (streaming_df.writeStream
    .format("delta")
    .outputMode("append")
    .option("checkpointLocation", "/Volumes/demoworkspace_new/default/my_volume/ecommerce/checkpoints/orders_stream")
    .trigger(availableNow=True)
    .table("orders_live"))

# %%
# %sql
SELECT * FROM 
json.`/Volumes/demoworkspace_new/default/my_volume/ecommerce/orders.json`

# %%
# %sql
SELECT * FROM 
binaryFile.`/Volumes/demoworkspace_new/default/my_volume/ecommerce/*.json`;
