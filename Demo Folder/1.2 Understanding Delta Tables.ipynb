-- %%
USE CATALOG demoworkspace_new

-- %%
CREATE TABLE employees
  (id INT, name STRING, salary DOUBLE);

-- %%
INSERT INTO employees
VALUES 
  (1, "Adam", 3500.0),
  (2, "Sarah", 4020.5);

INSERT INTO employees
VALUES
  (3, "John", 2999.3),
  (4, "Thomas", 4000.3);

INSERT INTO employees
VALUES
  (5, "Anna", 2500.0);

INSERT INTO employees
VALUES
  (6, "Kim", 6200.3)

-- %%
SELECT * FROM employees

-- %%
DESCRIBE DETAIL employees

-- %%
DESCRIBE HISTORY employees

-- %%
UPDATE employees 
SET salary = salary + 100
WHERE name LIKE "A%"

-- %%
SELECT * FROM employees

-- %%
DESCRIBE HISTORY employees

-- %%
DESCRIBE HISTORY employees;

-- %%
DESCRIBE DETAIL employees;

-- %%
%python
display(dbutils.fs.ls("abfss://unity-catalog-storage@dbstorageb3e5vgewgi4ie.dfs.core.windows.net/7405618761365455/__unitystorage/catalogs/93994ef1-7158-4fe8-bcc3-b889031cdcdc/tables/1ef69501-3f22-407a-bbb2-0e1e7c88ea08"))
